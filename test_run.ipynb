# %%
import sys
import json
import os
from src.data.generate_dataset import *
import run
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# pathing is weird

# %%
run.main()
# Out:
#                           created_at                   id  \
# 0     Fri Oct 02 04:25:52 +0000 2020  1311885083226169344
# 1     Fri Oct 02 04:44:14 +0000 2020  1311889706661994496
# 2     Fri Oct 02 04:59:03 +0000 2020  1311893436547715072
# 3     Fri Oct 02 05:35:50 +0000 2020  1311902690381881344
# 4     Fri Oct 02 05:45:16 +0000 2020  1311905064659771393
# ...                              ...                  ...
# 9047  Sat Oct 03 02:11:41 +0000 2020  1312213702850961409
# 9048  Sat Oct 03 02:45:07 +0000 2020  1312222119472902149
# 9049  Sat Oct 03 03:05:02 +0000 2020  1312227131536158723
# 9050  Sat Oct 03 03:37:24 +0000 2020  1312235274731048966
# 9051  Sat Oct 03 03:55:51 +0000 2020  1312239916651180033
#
#                    id_str                                          full_text  \
# 0     1311885083226169344  #TheTrumpDepression #BidenIsWinning\n#JoeBiden...
# 1     1311889706661994496  @Roscommon_Cat What's the bet we won't get his...
# 2     1311893436547715072         HAAHAJSKDLEKDLELDL https://t.co/l9OZSTbrrF
# 3     1311902690381881344  #Trump just tested positive for #COVID19\n\nht...
# 4     1311905064659771393  woj in shambles after this one https://t.co/GV...
# ...                   ...                                                ...
# 9047  1312213702850961409  Venezuela recibe un cargamento de Sputnik V y ...
# 9048  1312222119472902149  President Trump is now at Walter Reed National...
# 9049  1312227131536158723  @CNN You cannot abandon the rule of law for ev...
# 9050  1312235274731048966  If all of the events, negligence, and mockery ...
# 9051  1312239916651180033  @sugawitter I am praying for Mr and Ms. Presid...
#
#       truncated display_text_range  \
# 0         False           [0, 278]
# 1         False          [15, 294]
# 2         False            [0, 18]
# 3         False            [0, 65]
# 4         False            [0, 30]
# ...         ...                ...
# 9047      False           [0, 154]
# 9048      False           [0, 196]
# 9049      False           [5, 212]
# 9050      False           [0, 247]
# 9051      False           [12, 93]
#
#                                                entities  \
# 0     {'hashtags': [{'text': 'TheTrumpDepression', '...
# 1     {'hashtags': [], 'symbols': [], 'user_mentions...
# 2     {'hashtags': [], 'symbols': [], 'user_mentions...
# 3     {'hashtags': [{'text': 'Trump', 'indices': [0,...
# 4     {'hashtags': [], 'symbols': [], 'user_mentions...
# ...                                                 ...
# 9047  {'hashtags': [], 'symbols': [], 'user_mentions...
# 9048  {'hashtags': [], 'symbols': [], 'user_mentions...
# 9049  {'hashtags': [{'text': 'MichiganSupremeCourt',...
# 9050  {'hashtags': [{'text': 'COVID19', 'indices': [...
# 9051  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/android" ...
# 1     <a href="https://mobile.twitter.com" rel="nofo...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/android" ...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 9047  <a href="https://mobile.twitter.com" rel="nofo...
# 9048  <a href="http://www.socialflow.com" rel="nofol...
# 9049  <a href="http://twitter.com/download/android" ...
# 9050  <a href="https://mobile.twitter.com" rel="nofo...
# 9051  <a href="https://mobile.twitter.com" rel="nofo...
#
#       in_reply_to_status_id  in_reply_to_status_id_str  ...  \
# 0                       NaN                        NaN  ...
# 1              1.311881e+18               1.311881e+18  ...
# 2                       NaN                        NaN  ...
# 3                       NaN                        NaN  ...
# 4                       NaN                        NaN  ...
# ...                     ...                        ...  ...
# 9047                    NaN                        NaN  ...
# 9048                    NaN                        NaN  ...
# 9049           1.312211e+18               1.312211e+18  ...
# 9050                    NaN                        NaN  ...
# 9051           1.312144e+18               1.312144e+18  ...
#
#                                 quoted_status_permalink  \
# 0     {'url': 'https://t.co/K3uEqIKDvf', 'expanded':...
# 1                                                   NaN
# 2     {'url': 'https://t.co/l9OZSTbrrF', 'expanded':...
# 3                                                   NaN
# 4     {'url': 'https://t.co/GVmt9337To', 'expanded':...
# ...                                                 ...
# 9047                                                NaN
# 9048                                                NaN
# 9049                                                NaN
# 9050                                                NaN
# 9051                                                NaN
#
#                                           quoted_status retweet_count  \
# 0     {'created_at': 'Fri Oct 02 01:12:32 +0000 2020...             0
# 1                                                   NaN             0
# 2     {'created_at': 'Fri Oct 02 04:56:04 +0000 2020...             0
# 3                                                   NaN             0
# 4     {'created_at': 'Fri Oct 02 04:54:31 +0000 2020...             0
# ...                                                 ...           ...
# 9047                                                NaN             0
# 9048                                                NaN            17
# 9049                                                NaN             0
# 9050                                                NaN             0
# 9051                                                NaN             0
#
#      favorite_count favorited retweeted possibly_sensitive  lang  \
# 0                 0     False     False              False   und
# 1                 2     False     False                NaN    en
# 2                 0     False     False              False    fi
# 3                 0     False     False              False    en
# 4                 1     False     False              False    en
# ...             ...       ...       ...                ...   ...
# 9047              0     False     False              False    es
# 9048             87     False     False              False    en
# 9049              0     False     False                NaN    en
# 9050              0     False     False              False    en
# 9051              5     False     False                NaN    en
#
#       extended_entities                                           hashtags
# 0                   NaN  ['TheTrumpDepression', 'BidenIsWinning', 'JoeB...
# 1                   NaN                                                 []
# 2                   NaN                                                 []
# 3                   NaN                               ['Trump', 'COVID19']
# 4                   NaN                                                 []
# ...                 ...                                                ...
# 9047                NaN                                                 []
# 9048                NaN                                                 []
# 9049                NaN  ['MichiganSupremeCourt', 'Whitmer', 'COVID19',...
# 9050                NaN                                        ['COVID19']
# 9051                NaN                                                 []
#
# [9052 rows x 31 columns]

# %%
with open('data/temp/tweets_hydrated.jsonl') as fh:
    json_content = fh.read()

# %%
with open('~/dsc180_project_structure/data/temp/tweets_hydrated.jsonl') as fh:
    json_content = fh.read()
# Out:
# FileNotFoundErrorTraceback (most recent call last)
# <ipython-input-12-d659622df224> in <module>
# ----> 1 with open('~/dsc180_project_structure/data/temp/tweets_hydrated.jsonl') as fh:
#       2     json_content = fh.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: '~/dsc180_project_structure/data/temp/tweets_hydrated.jsonl'
